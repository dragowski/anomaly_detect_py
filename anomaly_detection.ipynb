# %%
'''
Purpose of this dataset: 
    Is to facilitate research, analysis, and development of intrusion detection systems,
    anomaly detection algorithms and other security mechanisms for substation networks using the Modbus protocol
    
Attack scenarios: 
    The dataset covers attacks conducted in three different scenarios: 
    attacks from devices external to the network, attacks from compromised IEDs and attacks
    from compromised Human-Machine Interfaces (HMIs). Each scenario generated specific logs 
    capturing the corresponding attack activity.

Atacks:
    Reconnaissance,
    query flooding, 
    loading payloads, 
    delay response, 
    modify length parameters, 
    false data injection, 
    stacking Modbus frames, 
    brute force write 
    baseline replay
    based on MITRE ICS ATT&CK framework
    
Data Format:
    Network captures: 
        The network captures are stored in PCAP (Packet Capture) format. 
        The captures are chunked into 100MB files, named in sequential order and each file represents
        a portion of the overall network traffic.
    Logs: 
        The logs generated by the attack tools and the trust model are stored in CSV (Comma-Separated Values) format.
        The logs are grouped by dates, and each record within the log files is timestamped, providing a chronological 
        view of the captured events.

IPs of the devices:

Secure IEDs
IED1A  185.175.0.4
IED4C  185.175.0.8
Normal IEDs
IED1B  185.175.0.5
Secure SCADA HMI  185.175.0.2
Normal SCADA HMI  185.175.0.3
Central Agent  185.175.0.6
Attacker  185.175.0.7
'''
'C:/Users/gabri/OneDrive/Área de Trabalho/5_periodo/SI/Modbus Dataset/Modbus Dataset/attack/compromised-scada/ied1b/ied1b-network-captures/vethc76bd3f-0.pcap'
# Out:
# 'C:/Users/gabri/OneDrive/Área de Trabalho/5_periodo/SI/Modbus Dataset/Modbus Dataset/attack/compromised-scada/ied1b/ied1b-network-captures/vethc76bd3f-0.pcap'

# %%
import pandas as pd

#Carregando os pacotes em um dataframe do pandas
dfWideNetwork = pd.read_csv('wideNetwork.csv', header = None, names = ['Timestamp', 'PackLenght', 'SourceAddress', 'DestAddress', 'Protocol', 'TTL', 'SourcePort', 'DestPort', 'WindowSize', 'SequenceNumber', 'Reserved', 'Accurate', 'CWR', 'ECN_Echo', 'Urgent', 'Acknowledgement', 'Push', 'Reset', 'Syn', 'Attacked', 'AttackType'])
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_27568\1146710067.py:4: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfWideNetwork = pd.read_csv('wideNetwork.csv', header = None, names = ['Timestamp', 'PackLenght', 'SourceAddress', 'DestAddress', 'Protocol', 'TTL', 'SourcePort', 'DestPort', 'WindowSize', 'SequenceNumber', 'Reserved', 'Accurate', 'CWR', 'ECN_Echo', 'Urgent', 'Acknowledgement', 'Push', 'Reset', 'Syn', 'Attacked', 'AttackType'])

# %%
dfWideNetwork.head()
# Out:
#                  Timestamp  PackLenght SourceAddress  DestAddress  Protocol  \
# 0  2023-02-01 03:49:36.443          66   185.175.0.3  185.175.0.4         6
# 1  2023-02-01 03:49:36.443          66   185.175.0.3  185.175.0.4         6
# 2  2023-02-01 03:49:36.459          66   185.175.0.4  185.175.0.3         6
# 3  2023-02-01 03:49:36.464          74   185.175.0.3  185.175.0.4         6
# 4  2023-02-01 03:49:36.464          74   185.175.0.4  185.175.0.3         6
#
#    TTL  SourcePort  DestPort  WindowSize  SequenceNumber  ...  Accurate  \
# 0   64       53496       502       64256      1235332397  ...     False
# 1   64       53496       502       64256      1235332397  ...     False
# 2   64         502     53494       65152      1919784539  ...     False
# 3   64       53498       502       64240      4126181854  ...     False
# 4   64         502     53498       65160      3143922994  ...     False
#
#      CWR  ECN_Echo  Urgent  Acknowledgement   Push  Reset    Syn  Attacked  \
# 0  False     False   False             True  False  False  False     False
# 1  False     False   False             True  False  False  False     False
# 2  False     False   False             True  False  False  False     False
# 3  False     False   False            False  False  False   True     False
# 4  False     False   False             True  False  False   True     False
#
#    AttackType
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 21 columns]

# %%
dfWideNetwork.columns
# Out:
# Index(['Timestamp', 'PackLenght', 'SourceAddress', 'DestAddress', 'Protocol',
#        'TTL', 'SourcePort', 'DestPort', 'WindowSize', 'SequenceNumber',
#        'Reserved', 'Accurate', 'CWR', 'ECN_Echo', 'Urgent', 'Acknowledgement',
#        'Push', 'Reset', 'Syn', 'Attacked', 'AttackType'],
#       dtype='object')

# %%
dfWideNetwork.describe()
# Out:
#          PackLenght  Protocol      TTL    SourcePort      DestPort  \
# count  90942.000000   90942.0  90942.0  90942.000000  90942.000000
# mean      69.562996       6.0     64.0  29478.913296  23251.316751
# std       12.538257       0.0      0.0  26485.128690  26501.022130
# min       54.000000       6.0     64.0    502.000000    502.000000
# 25%       66.000000       6.0     64.0    502.000000    502.000000
# 50%       66.000000       6.0     64.0  34844.000000    502.000000
# 75%       74.000000       6.0     64.0  56476.000000  55464.000000
# max      342.000000       6.0     64.0  60998.000000  60998.000000
#
#          WindowSize  SequenceNumber
# count  90942.000000    9.094200e+04
# mean   61519.273724    2.144228e+09
# std    13915.817057    1.236916e+09
# min        0.000000    4.545410e+05
# 25%    64256.000000    1.079583e+09
# 50%    64256.000000    2.151377e+09
# 75%    65152.000000    3.210437e+09
# max    65280.000000    4.294705e+09

# %%
 ! pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\gabri\appdata\local\programs\python\python310\lib\site-packages (2.0.1)
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# Load the dataset
df = dfWideNetwork

# Drop columns that might not be useful for the model
X = df.drop(columns=['Timestamp', 'Attacked', 'AttackType'])
y = df['Attacked']

# Split the dataset while keeping the same proportion of values in the target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Create and train the XGBoost model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_model.fit(X_train, y_train)

# Make predictions
y_pred = xgb_model.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: Não foi possível encontrar o módulo especificado.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.10 from "C:\Users\gabri\AppData\Local\Programs\Python\Python310\python.exe"
#   * The NumPy version is: "1.23.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: Não foi possível encontrar o módulo especificado.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.model_selection import train_test_split
#       3 from xgboost import XGBClassifier
#       4 from sklearn.metrics import accuracy_score
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      87     __all__ = [
#      88         "calibration",
#      89         "cluster",
#    (...)
#     130         "show_versions",
#     131     ]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\__init__.py:11
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      14 # Make _safe_indexing importable from here for backward compat as this particular
#      15 # helper is considered semi-private and typically very useful for third-party
#      16 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      17 # _safe_indexing was included in our public API documentation despite the leading
#      18 # `_` in its name.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_chunking.py:8
#       5 import numpy as np
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#      11 def chunk_generator(gen, chunksize):
#      12     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      13     chunk may have a length less than ``chunksize``."""
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:11
#       8 from numbers import Integral, Real
#      10 import numpy as np
# ---> 11 from scipy.sparse import csr_matrix, issparse
#      13 from .._config import config_context, get_config
#      14 from .validation import _is_arraylike_not_scalar
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\__init__.py:294
#     291 import warnings as _warnings
#     293 from ._base import *
# --> 294 from ._csr import *
#     295 from ._csc import *
#     296 from ._lil import *
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_csr.py:11
#       9 from ._matrix import spmatrix
#      10 from ._base import _spbase, sparray
# ---> 11 from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
#      12                            get_csr_submatrix)
#      13 from ._sputils import upcast
#      15 from ._compressed import _cs_matrix
#
# ImportError: nump
# 29882  2023-02-01 04:04:55.453          66   185.175.0.7  185.175.0.4
# 29883  2023-02-01 04:04:55.453          66   185.175.0.4  185.175.0.7
#
#        Protocol  TTL  SourcePort  DestPort  WindowSize  SequenceNumber  ...  \
# 5065          6   64         502     55036       65280      2200038312  ...
# 5066          6   64       55036       502       64256       148567540  ...
# 5067          6   64         502     55036           0      2200038313  ...
# 6992          6   64       55038       502       64256      2756724017  ...
# 6993          6   64         502     55038       65152      3316525133  ...
# 6994          6   64       55038       502       64256      2756724029  ...
# 17213         6   64       55040       502       64240      2166275241  ...
# 17214         6   64         502     55040       65160      1136822645  ...
# 17215         6   64       55040       502       64256      2166275242  ...
# 17216         6   64       55040       502       64256      2166275242  ...
# 17217         6   64         502     55040       65152      1136822646  ...
# 17218         6   64       55040       502       64256      2166275254  ...
# 19525         6   64       55042       502       64240      1329096559  ...
# 19526         6   64         502     55042       65160      1599386128  ...
# 19527         6   64       55042       502       64256      1329096560  ...
# 19528         6   64       55042       502       64256      1329096560  ...
# 19529         6   64         502     55042       65152      1599386129  ...
# 19530         6   64         502     55042       65152      1599386129  ...
# 19531         6   64         502     55042       65152      1599386130  ...
# 28791         6   64       55046       502       64240      2727340913  ...
# 28792         6   64         502     55046       65160       599542743  ...
# 28793         6   64       55046       502       64256      2727340914  ...
# 28794         6   64         502     55046       65280       599542744  ...
# 28795         6   64       55046       502       64256      2727340914  ...
# 28796         6   64         502     55046       65280       599542745  ...
# 28797         6   64         502     55046       65280       599542745  ...
# 28798         6   64       55046       502       64256      2727340926  ...
# 28799         6   64         502     55046           0       599542745  ...
# 29416         6   64       55050       502       64240      1701310231  ...
# 29417         6   64         502     55050       65160      1105743450  ...
# 29418         6   64       55050       502       64256      1701310232  ...
# 29419         6   64       55050       502       64256      1701310232  ...
# 29420         6   64         502     55050       65152      1105743451  ...
# 29421         6   64       55050       502       64256      1701310244  ...
# 29876         6   64       55052       502       64240      3280070448  ...
# 29877         6   64         502     55052       65160      1950521334  ...
# 29878         6   64       55052       502       64256      3280070449  ...
# 29879         6   64       55052       502       64256      3280070449  ...
# 29880         6   64         502     55052       65280      1950521335  ...
# 29881         6   64         502     55052       65280      1950521336  ...
# 29882         6   64       55052       502       64256      3280070461  ...
# 29883         6   64         502     55052       65280      1950521336  ...
#
#        Accurate    CWR  ECN_Echo  Urgent  Acknowledgement   Push  Reset  \
# 5065      False  False     False   False             True  False  False
# 5066      False  False     False   False             True   True  False
# 5067      False  False     False   False            False  False   True
# 6992      False  False     False   False             True   True  False
# 6993      False  False     False   False             True  False  False
# 6994      False  False     False   False             True  False  False
# 17213     False  False     False   False            False  False  False
# 17214     False  False     False   False             True  False  False
# 17215     False  False     False   False             True  False  False
# 17216     False  False     False   False             True   True  False
# 17217     False  False     False   False             True  False  False
# 17218     False  False     False   False             True  False  False
# 19525     False  False     False   False            False  False  False
# 19526     False  False     False   False             True  False  False
# 19527     False  False     False   False             True  False  False
# 19528     False  False     False   False             True   True  False
# 19529     False  False     False   False             True  False  False
# 19530     False  False     False   False             True  False  False
# 19531     False  False     False   False             True  False   True
# 28791     False  False     False   False            False  False  False
# 28792     False  False     False   False             True  False  False
# 28793     False  False     False   False             True  False  False
# 28794     False  False     False   False             True  False  False
# 28795     False  False     False   False             True   True  False
# 28796     False  False     False   False             True  False  False
# 28797     False  False     False   False             True  False   True
# 28798     False  False     False   False             True  False  False
# 28799     False  False     False   False            False  False   True
# 29416     False  False     False   False            False  False  False
# 29417     False  False     False   False             True  False  False
# 29418     False  False     False   False             True  False  False
# 29419     False  False     False   False             True   True  False
# 29420     False  False     False   False             True  False  False
# 29421     False  False     False   False             True  False  False
# 29876     False  False     False   False            False  False  False
# 29877     False  False     False   False             True  False  False
# 29878     False  False     False   False             True  False  False
# 29879     False  False     False   False             True   True  False
# 29880     False  False     False   False             True  False  False
# 29881     False  False     False   False             True  False  False
# 29882     False  False     False   False             True  False  False
# 29883     False  False     False   False             True  False   True
#
#          Syn  Attacked           AttackType
# 5065   False      True  Recon. Range: 65535
# 5066   False      True  Recon. Range: 65535
# 5067   False      True  Recon. Range: 65535
# 6992   False      True                  NaN
# 6993   False      True                  NaN
# 6994   False      True                  NaN
# 17213   True      True                  NaN
# 17214   True      True                  NaN
# 17215  False      True                  NaN
# 17216  False      True                  NaN
# 17217  False      True                  NaN
# 17218  False      True                  NaN
# 19525   True      True                  NaN
# 19526   True      True                  NaN
# 19527  False      True                  NaN
# 19528  False      True                  NaN
# 19529  False      True                  NaN
# 19530  False      True                  NaN
# 19531  False      True                  NaN
# 28791   True      True                  NaN
# 28792   True      True                  NaN
# 28793  False      True                  NaN
# 28794  False      True                  NaN
# 28795  False      True                  NaN
# 28796  False      True                  NaN
# 28797  False      True                  NaN
# 28798  False      True                  NaN
# 28799  False      True                  NaN
# 29416   True      True                  NaN
# 29417   True      True                  NaN
# 29418  False      True                  NaN
# 29419  False      True                  NaN
# 29420  False      True                  NaN
# 29421  False      True                  NaN
# 29876   True      True                  NaN
# 29877   True      True                  NaN
# 29878  False      True                  NaN
# 29879  False      True                  NaN
# 29880  False      True                  NaN
# 29881  False      True                  NaN
# 29882  False      True                  NaN
# 29883  False      True                  NaN
#
# [42 rows x 21 columns]

# %%
print(dfWideNetwork.iloc[6993])
# Out:
# Timestamp          2023-02-01 03:52:46.776
# PackLenght                              66
# SourceAddress                  185.175.0.4
# DestAddress                    185.175.0.7
# Protocol                                 6
# TTL                                     64
# SourcePort                             502
# DestPort                             55038
# WindowSize                           65152
# SequenceNumber                  3316525133
# Reserved                             False
# Accurate                             False
# CWR                                  False
# ECN_Echo                             False
# Urgent                               False
# Acknowledgement                       True
# Push                                 False
# Reset                                False
# Syn                                  False
# Attacked                             False
# AttackType                             NaN
# Name: 6993, dtype: object

# %%
dfWideNetwork
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dfWideNetwork
#
# NameError: name 'dfWideNetwork' is not defined
